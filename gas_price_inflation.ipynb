# %%
import os
import requests
import json
import pandas as pd
import prettytable
from pathlib import Path
import csv

# %%
#API Call for 4 US Regions

headers = {'Content-type': 'application/json'}
series_id = ['APU010074714','APU020074714', 'APU030074714', 'APU040074714']
data = json.dumps({"seriesid": series_id,"startyear":"2015", "endyear":"2021"})
p = requests.post('https://api.bls.gov/publicAPI/v2/timeseries/data/', data=data, headers=headers)
json_data = json.loads(p.text)
df = pd.json_normalize(json_data['Results']['series'], "data", ["seriesID"])
df
# Out:
#      year period periodName latest  value footnotes      seriesID
# 0    2021    M11   November   true  3.506      [{}]  APU010074714
# 1    2021    M10    October    NaN  3.374      [{}]  APU010074714
# 2    2021    M09  September    NaN  3.223      [{}]  APU010074714
# 3    2021    M08     August    NaN  3.187      [{}]  APU010074714
# 4    2021    M07       July    NaN  3.155      [{}]  APU010074714
# ..    ...    ...        ...    ...    ...       ...           ...
# 327  2015    M05        May    NaN  3.346      [{}]  APU040074714
# 328  2015    M04      April    NaN  2.849      [{}]  APU040074714
# 329  2015    M03      March    NaN  2.917      [{}]  APU040074714
# 330  2015    M02   February    NaN  2.457      [{}]  APU040074714
# 331  2015    M01    January    NaN  2.243      [{}]  APU040074714
#
# [332 rows x 7 columns]

# %%
#Setting the index of the df to seriesID
df.set_index("seriesID", inplace=True)

df
# Out:
#               year period periodName latest  value footnotes
# seriesID
# APU010074714  2021    M11   November   true  3.506      [{}]
# APU010074714  2021    M10    October    NaN  3.374      [{}]
# APU010074714  2021    M09  September    NaN  3.223      [{}]
# APU010074714  2021    M08     August    NaN  3.187      [{}]
# APU010074714  2021    M07       July    NaN  3.155      [{}]
# ...            ...    ...        ...    ...    ...       ...
# APU040074714  2015    M05        May    NaN  3.346      [{}]
# APU040074714  2015    M04      April    NaN  2.849      [{}]
# APU040074714  2015    M03      March    NaN  2.917      [{}]
# APU040074714  2015    M02   February    NaN  2.457      [{}]
# APU040074714  2015    M01    January    NaN  2.243      [{}]
#
# [332 rows x 6 columns]

# %%
#Reading the series_id.csv file with furhter information abour the series.
seriesid_df = pd.read_csv(
    Path("Resources/series_id.csv")
)
seriesid_df.head()
# Out:
#         seriesID area_code item_code  \
# 0  APU0000701111         0    701111
# 1  APU0000701311         0    701311
# 2  APU0000701312         0    701312
# 3  APU0000701321         0    701321
# 4  APU0000701322         0    701322
#
#                                         series_title  footnote_codes  \
# 0  Flour, white, all purpose, per lb. (453.6 gm) ...             NaN
# 1  Rice, white, long grain, precooked (cost per p...             NaN
# 2  Rice, white, long grain, uncooked, per lb. (45...             NaN
# 3  Spaghetti (cost per pound/453.6 grams) in U.S....             NaN
# 4  Spaghetti and macaroni, per lb. (453.6 gm) in ...             NaN
#
#    begin_year begin_period  end_year end_period
# 0        1980          M01      2021        M10
# 1        1980          M01      1981        M12
# 2        1980          M01      2021        M10
# 3        1980          M01      1981        M03
# 4        1984          M01      2021        M10

# %%
seriesid_df.set_index("seriesID", inplace=True)

seriesid_df
# Out:
#               area_code item_code  \
# seriesID
# APU0000701111         0    701111
# APU0000701311         0    701311
# APU0000701312         0    701312
# APU0000701321         0    701321
# APU0000701322         0    701322
# ...                 ...       ...
# APUS49G74713       S49G     74713
# APUS49G74714       S49G     74714
# APUS49G74715       S49G     74715
# APUS49G74716       S49G     74716
# APUS49G7471A       S49G     7471A
#
#                                                     series_title  \
# seriesID
# APU0000701111  Flour, white, all purpose, per lb. (453.6 gm) ...
# APU0000701311  Rice, white, long grain, precooked (cost per p...
# APU0000701312  Rice, white, long grain, uncooked, per lb. (45...
# APU0000701321  Spaghetti (cost per pound/453.6 grams) in U.S....
# APU0000701322  Spaghetti and macaroni, per lb. (453.6 gm) in ...
# ...                                                          ...
# APUS49G74713   Gasoline, leaded premium (cost per gallon/3.8 ...
# APUS49G74714   Gasoline, unleaded regular, per gallon/3.785 l...
# APUS49G74715   Gasoline, unleaded midgrade, per gallon/3.785 ...
# APUS49G74716   Gasoline, unleaded premium, per gallon/3.785 l...
# APUS49G7471A   Gasoline, all types, per gallon/3.785 liters i...
#
#                footnote_codes  begin_year begin_period  end_year end_period
# seriesID
# APU0000701111             NaN        1980          M01      2021        M10
# APU0000701311             NaN        1980          M01      1981        M12
# APU0000701312             NaN        1980          M01      2021        M10
# APU0000701321             NaN        1980          M01      1981        M03
# APU0000701322             NaN        1984          M01      2021        M10
# ...                       ...         ...          ...       ...        ...
# APUS49G74713              NaN        1978          M01      1981        M04
# APUS49G74714              NaN        1978          M01      2021        M10
# APUS49G74715              NaN        2021          M06      2021        M10
# APUS49G74716              NaN        1981          M09      2021        M10
# APUS49G7471A              NaN        1978          M01      2021        M10
#
# [1481 rows x 8 columns]

# %%
gas_df = pd.merge(df, seriesid_df, on="seriesID")
gas_df
# Out:
#               year period periodName latest  value footnotes area_code  \
# seriesID
# APU010074714  2021    M11   November   true  3.506      [{}]       100
# APU010074714  2021    M10    October    NaN  3.374      [{}]       100
# APU010074714  2021    M09  September    NaN  3.223      [{}]       100
# APU010074714  2021    M08     August    NaN  3.187      [{}]       100
# APU010074714  2021    M07       July    NaN  3.155      [{}]       100
# ...            ...    ...        ...    ...    ...       ...       ...
# APU040074714  2015    M05        May    NaN  3.346      [{}]       400
# APU040074714  2015    M04      April    NaN  2.849      [{}]       400
# APU040074714  2015    M03      March    NaN  2.917      [{}]       400
# APU040074714  2015    M02   February    NaN  2.457      [{}]       400
# APU040074714  2015    M01    January    NaN  2.243      [{}]       400
#
#              item_code                                       series_title  \
# seriesID
# APU010074714     74714  Gasoline, unleaded regular, per gallon/3.785 l...
# APU010074714     74714  Gasoline, unleaded regular, per gallon/3.785 l...
# APU010074714     74714  Gasoline, unleaded regular, per gallon/3.785 l...
# APU010074714     74714  Gasoline, unleaded regular, per gallon/3.785 l...
# APU010074714     74714  Gasoline, unleaded regular, per gallon/3.785 l...
# ...                ...                                                ...
# APU040074714     74714  Gasoline, unleaded regular, per gallon/3.785 l...
# APU040074714     74714  Gasoline, unleaded regular, per gallon/3.785 l...
# APU040074714     74714  Gasoline, unleaded regular, per gallon/3.785 l...
# APU040074714     74714  Gasoline, unleaded regular, per gallon/3.785 l...
# APU040074714     74714  Gasoline, unleaded regular, per gallon/3.785 l...
#
#               footnote_codes  begin_year begin_period  end_year end_period
# seriesID
# APU010074714             NaN        1978          M01      2021        M10
# APU010074714             NaN        1978          M01      2021        M10
# APU010074714             NaN        1978          M01      2021        M10
# APU010074714             NaN        1978          M01      2021        M10
# APU010074714             NaN        1978          M01      2021        M10
# ...                      ...         ...          ...       ...        ...
# APU040074714             NaN        1978          M01      2021        M10
# APU040074714             NaN        1978          M01      2021        M10
# APU040074714             NaN        1978          M01      2021        M10
# APU040074714             NaN        1978          M01      2021        M10
# APU040074714             NaN        1978          M01      2021        M10
#
# [332 rows x 14 columns]

# %%
#Defining variables for commuting assumptions
#Assumming different commute miles roundtrip per work day per region
weekly_commute_west_before=150
weekly_commute_midwest_before=120
weekly_commute_northeast_before=75
weekly_commute_south_before=60
#Hybrid work model requires 2 days work in office compared to 5 days before
#Creating a variable to calculate delta
weekly_commute_change=1-(2/5)

# %%
#Building a dataframe with commute data per area (0400=West, 0300=South ,0100=NorthEast, 0200=Midwest)
d = {'area_code': [100,200,300,400], 'Average Commute Before': [75,120,60,150]}
commute_df = pd.DataFrame(data=d,)
commute_df.set_index('area_code', inplace=True)
commute_df[]
# Out:
# pandas.core.series.Series

# %%
#Add Commute Savings
commute_df['Commute Savings']=commute_df['Average Commute Before']*weekly_commute_change
commute_df
# Out:
#    area_code  Average Commute Before  Commute Savings
# 0        100                      75             45.0
# 1        200                     120             72.0
# 2        300                      60             36.0
# 3        400                     150             90.0

# %%
#Merging commute df with the gas prices df
final_df=pd.merge(gas_df,commute_df, on='area_code')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26648/531041182.py in <module>
#       1 #Merging commute df with the gas prices df
# ----> 2 final_df=pd.merge(gas_df,commute_df, on='area_code')
#
# ~\.conda\envs\dev\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     117         copy=copy,
#     118         indicator=indicator,
# --> 119         validate=validate,
#     120     )
#     121     return op.get_result()
#
# ~\.conda\envs\dev\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     701         # validate the merge keys dtypes. We may need to coerce
#     702         # to avoid incompatible dtypes
# --> 703         self._maybe_coerce_merge_keys()
#     704
#     705         # If argument passed to validate,
#
# ~\.conda\envs\dev\lib\site-packages\pandas\core\reshape\merge.py in _maybe_coerce_merge_keys(self)
#    1254                     inferred_right in string_types and inferred_left not in string_types
#    1255                 ):
# -> 1256                     raise ValueError(msg)
#    1257
#    1258             # datetimelikes must match exactly
#
# ValueError: You are trying to merge on object and int64 columns. If you wish to proceed you should use pd.concat

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\.conda\envs\dev\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\.conda\envs\dev\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\.conda\envs\dev\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'area_code'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26648/213045993.py in <module>
# ----> 1 commute_df[commute_df['area_code']]
#
# ~\.conda\envs\dev\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\.conda\envs\dev\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'area_code'
